# %%
""" 10. Find error(s) in the following code(if any) and rewrite code. """
try:
  x = int(input("Enter value of x:"))
  flag=0
  for y in range(0,10):     
     if(x==y):
          flag=1
          print(x,"is present in the range of values from 0 to 9")
          break
  if(flag==0):
         print(x,"is not present in the range of values from 0 to 9")
except ValueError:
  print("That was not a number!")
# Out:
# Enter value of x:9
# 9 is present in the range of values from 0 to 9
